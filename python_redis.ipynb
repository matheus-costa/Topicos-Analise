# %%
# -*- coding: utf-8 -*-
"""conexao_redis.ipynb

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/drive/1oYxCw-XbSc8ANVuE6pftzY9Z4a9C5piI
"""

# !pip install redis
import redis

#conexão com o redis cloud (usar o banco de dados de vocês, esse é um antigo do professor)
# https://redis.io/
client = redis.Redis(host="redis-11205.c12.us-east-1-4.ec2.redns.redis-cloud.com", port=11205, db=0, password='VtL9uhjBlaL6PTpk11EHyxPhT8RyAeE4')
#teste de conexão ping responde pong o servidor

client.ping()
# Out:
# ...
# True

# %%
client.ping()

#setando uma chave e um valor
client.set('book', 'Tiago Potter')
#lendo o valor pela chave book

client.get('book')
# Out:
# b'Tiago Potter'

# %%
#gravando um hash
client.hset("ifsul:ender", "campus", "Bage")
client.hset("ifsul:ender", "rua", "Leonel Moura Brizola")
client.hset("ifsul:ender", "numero", "2501")
client.hset("ifsul:ender","bairro","pedra branca")
client.hset("ifsul:ender","cep","96418-400")
client.hset("ifsul:ender","uf","RS")

#retornando um valor específico pela chave

print(client.hget("ifsul:ender", "rua"))

client.close
# Out:
# b'Leonel Moura Brizola'
